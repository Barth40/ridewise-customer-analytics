# %%
# Load featured dataset
df = pd.read_csv("../data/processed/featured_dataset.csv")

# Create churn target
df["is_churned"] = (df["churn_prob"] >= 0.5).astype(int)

# Check class balance
print(df["is_churned"].value_counts())
print(df["is_churned"].value_counts(normalize=True) * 100)
